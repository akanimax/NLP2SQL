# %% [markdown]
# # Script to create a seq2seq model for training on the given data
# -----------------------------------------------------------------------------------------------------------------
# # Technology used: Tensorflow

# %% [markdown]
# I start with the usual cells for utility purposes.

# %%
# packages used for processing: 
import cPickle as pickle # for reading the data
import matplotlib.pyplot as plt # for visualization
import numpy as np

# for operating system related stuff
import os
import sys # for memory usage of objects
from subprocess import check_output

# the boss of frameworks
import tensorflow as tf

# for dataset building:
import collections

# for regex based preprocessing
import re

# to plot the images inline
# %matplotlib inline

# %%
# Input data files are available in the "../Data/" directory.

def exec_command(cmd):
    '''
        function to execute a shell command and see it's 
        output in the python console
        @params
        cmd = the command to be executed along with the arguments
              ex: ['ls', '../input']
    '''
    print(check_output(cmd).decode("utf8"))

# %%
# check the structure of the project directory
exec_command(['ls', '..'])
# Out:
# Data
# Models
# Scripts

# %%
''' !!! WARNING !!! '''
''' PLEASE DO NOT MODIFY THE BATCH_SIZE AND THE CHECKPOINT FACTOR! I HAVE SET IT PRECISELY 
SO AS NOT TO CRASH THE PC '''

''' Set the constants for the script '''

# various paths of the files
data_path = "../Data/WikiSQL/data" # the data path

train_files = {
    "questions": os.path.join(data_path, "train.jsonl"),
    "tables": os.path.join(data_path, "train.tables.jsonl")
}

base_model_path = '../Models'

processed_data_file_path = os.path.join(data_path, "processed.pickle")
plug_and_play_data_file_path = os.path.join(data_path, "plug_and_play.pickle")

# constants:
matcher_regex = r"[\w']+|[.,!?;\"]"
vocab_size = 55000 # total words in our vocabulary
lstm_hidden_state_size = 512 # hidden state size
seqs_length = 85
no_of_epochs = 1000
batch_size = 16 # we look at only 64 examples in a single batch            
checkpoint_factor = 10 # save the model after every 5 epochs

# %%
# check the contents of the data path
exec_command(['ls', data_path])
# Out:
# dev.db
# dev.jsonl
# dev.tables.jsonl
# plug_and_play.pickle
# processed.pickle
# test.db
# test.jsonl
# test.tables.jsonl
# train.db
# train.jsonl
# train.tables.jsonl

# %%
# create a function to unpickle the data into a python object
def unpickle(pickle_file):
    '''
        function to unpickle the pickle file into a python compatible object
        @param
        pickle => the pickle file path
        @return => the unpickled object
    '''
    with open(pickle_file) as dumper:
        return pickle.load(dumper)

# %%
# load the processed pickled data into the script.
data = unpickle(processed_data_file_path)

queries = data["queries"]
questions = data["questions"]

# %%
len(questions), len(queries)
# Out:
# (61297, 61297)

# %% [markdown]
# ### Since all are questions, we can safely drop the question mark at the end of the question sentences
# ### Another reason for doing this is that some examples have a question mark while others don't
# ### Besides, there doesn't seem to be anything unique that can be learnt by adding it to the vocabulary

# %%
# drop question mark from end of all the questions if there exists one
for index in range(len(questions)):
    orig = questions[index]
    orig_ans = queries[index]
    
    # remove the question mark if it exists
    if(orig[-1] == '?'):
        # remove the question mark from the end of the sentence.
        orig = orig[:-1]
        
    # make everything lowercase:
    questions[index] = orig.lower()
    queries[index] = orig_ans.lower()

# %%
for _ in range(5):
    # now: check the ideal output for a random question from the dataset
    random_index = np.random.randint(questions.shape[0])

    print "Random sample from the dataset:\n"

    # print the natural language question:
    print "Natural_Language question: " + questions[random_index]
    print "SQL query for the same   : " + queries[random_index] + "\n\n"
# Out:
# Random sample from the dataset:
#
# Natural_Language question: which location has a score of chunichi dragons–0, nishitetsu lions–5
# SQL query for the same   : select location from <table> where score = chunichi dragons – 0, nishitetsu lions – 5
#
#
# Random sample from the dataset:
#
# Natural_Language question: who scored the highest points and how much against the raptors
# SQL query for the same   : select high points from <table> where team = raptors
#
#
# Random sample from the dataset:
#
# Natural_Language question: what's the lowest lane found for a mark of 8.09 pb
# SQL query for the same   : select min ( lane )  from <table> where mark = 8.09 pb
#
#
# Random sample from the dataset:
#
# Natural_Language question: what is the 1999-2000 team, when the height (cm) is less than 187, and when the birthplace is cloquet, minnesota
# SQL query for the same   : select 1999-2000 team from <table> where height (cm) < 187 and birthplace = cloquet, minnesota
#
#
# Random sample from the dataset:
#
# Natural_Language question: when the venue is mcg what is the home team
# SQL query for the same   : select home team from <table> where venue = mcg

# %%
type(questions), type(queries)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
# function to build the dataset for the given task:

def build_dataset(words, questions, queries, n_words):
    """Process raw inputs into a dataset."""
    count = [['<blank>', 0], ['<go>', 1], ['<eos>', 2], ['UNK', -1]] # start with this list.
    count.extend(collections.Counter(words).most_common(n_words - 1)) # this is inplace. i.e. has a side effect

    dictionary = dict() # initialize the dictionary to empty one
    # fill this dictionary with the most frequent words
    for word, _ in count:
        dictionary[word] = len(dictionary)
  
    # loop to replace all the rare words by the UNK token
    data_questions = list() # start with empty list
    data_queries = list()
    unk_count = 0 # counter for keeping track of the unknown words
    for question, query in zip(questions, queries):
        
        # first transform the question
        data = [] # initilalize to empty
        for word in question:
            if word in dictionary:
                index = dictionary[word]
            else:
                index = 0  # dictionary['UNK']
                unk_count += 1
            data.append(index)
        data_questions.append(data)
        
        # now transform the query
        data = [] # initilalize to empty
        for word in query:
            if word in dictionary:
                index = dictionary[word]
            else:
                index = 0  # dictionary['UNK']
                unk_count += 1
            data.append(index)
        data_queries.append(data)

    count[0][1] = unk_count # replace the earlier -1 by the so calculated unknown count

    print("Total rare words replaced: ", unk_count) # log the total replaced rare words
  
    # construct the reverse dictionary for the original dictionary
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

    # return all the relevant stuff	
    return data_questions, data_queries, count, dictionary, reversed_dictionary

# %%
# split the sentences into words
split_questions = map(lambda x: x.split(), questions)
split_queries = map(lambda x: x.split(), queries)

#small loop to put all the words together:
all_splits = map(lambda x: x.split(), list(questions) + list(queries))
all_words = []
for split_sentence in all_splits:
    all_words += split_sentence

# %%
print "All words in the dataset   : " + str(len(all_words))
print "unique words in the dataset: " + str(len(list(set(all_words))))
# Out:
# All words in the dataset   : 1473073
# unique words in the dataset: 55713

# %%
dquestions, dqueries, count, dictionary, reverse_dictionary = build_dataset(all_words, 
                                                                        split_questions, split_queries, vocab_size)
# Out:
# ('Total rare words replaced: ', 714)

# %%
print (dquestions[:3], dqueries[:3])
# Out:
# ([[184, 178, 11, 5, 281, 79, 19, 189, 424], [11, 12, 5, 441, 101, 7, 5, 161, 101, 1582, 23, 173, 155], [11, 12, 5, 265, 19, 189, 424]], [[8, 281, 6, 9, 7, 441, 53789, 4, 189, 424], [8, 441, 101, 6, 9, 7, 281, 4, 161, 101, 1582, 23, 173, 155], [8, 265, 6, 9, 7, 4677, 4, 189, 424]])

# %%
# add go and eos entry to every sequence. and then pad the sequence to the fixed length
index = 0
for (dquestion, dquery) in zip(dquestions, dqueries):
    dquery = [1] + dquery + [2]
    
    # pad the dquestion
    while(len(dquestion) != seqs_length):
        dquestion += [0]
    
    # pad the dquery:
    while(len(dquery) != seqs_length):
        dquery += [0]
    
    dqueries[index] = dquery
    dquestions[index] = dquestion
    index += 1

# %%
sum(map(lambda x: len(x), dquestions)) / len(dquestions), sum(map(lambda x: len(x), dqueries)) / len(dqueries)
# Out:
# (85, 85)

# %%
# again visualize a few sequences:
print [reverse_dictionary[i] for i in dquestions[0]]
# Out:
# [u'tell', u'me', u'what', u'the', u'notes', u'are', u'for', u'south', u'australia', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>', '<blank>']

# %%
# pickle the proper data so that we can use it in a plug and play manner
plug_and_play_data = {
    "dictionary": dictionary,
    "reverse_dictionary": reverse_dictionary,
    "questions": dquestions,
    "queries": dqueries
}

if(not os.path.isfile(plug_and_play_data_file_path)):
    with open(plug_and_play_data_file_path, 'wb') as dumping:
        pickle.dump(plug_and_play_data, dumping, pickle.HIGHEST_PROTOCOL)
else:
    print "The data has been pickled"
# Out:
# The data has been pickled

# %% [markdown]
# # So, now the data is processsed and ready for LSTM training

# %%
# Computation graph defining the network architecture of the model

graph = tf.Graph()

with graph.as_default():
    
    # constant to hold the training data and labels
    with tf.variable_scope("input"):
        input_data = [tf.placeholder(tf.int32, shape=(None), name="input_sequences")] # list of placeholders
        input_translation = [tf.placeholder(tf.int32, shape=(None), name="ideal_output_sequences")]
        
        loss_targets = tf.one_hot(tf.stack(input_translation), depth=len(dictionary.keys()))

    # create the basic_rnn_seq2seq
    outputs, states = tf.contrib.legacy_seq2seq.embedding_rnn_seq2seq (
                        input_data, # encoder input
                        input_translation, # decoder input
                        tf.contrib.rnn.LSTMCell(lstm_hidden_state_size),
                        len(dictionary.keys()),
                        len(dictionary.keys()),
                        128,
                        feed_previous = True,
                )
    
    # The output is now required for calculating the loss.
    with tf.variable_scope("loss"):
        # we use the euclidean loss as the measure of minimization
        # loss = tf.reduce_mean(tf.abs(tf.stack(outputs) - tf.stack(input_translation)), name="mean_loss")
        
        # changed the loss to softmax_cross_entropy_with_logits
        loss = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits(
                labels = loss_targets,
                logits = outputs
            ))
        loss_summary = tf.summary.scalar("loss_summary", loss)
        
    # define the op to calculate the predictions
    
    prediction = tf.squeeze(tf.argmax(outputs, axis = -1))
        
    
    # the train module for running the optimization op
    train_op = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)
    
    all_summaries = tf.summary.merge_all()
    
    init = tf.global_variables_initializer()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-688a9a6eeb4a> in <module>()
#      20                         len(dictionary.keys()),
#      21                         128,
# ---> 22                         feed_previous = True,
#      23                 )
#      24
#
# /home/animesh/Programming/platforms/anaconda3/envs/snakes/lib/python2.7/site-packages/tensorflow/contrib/legacy_seq2seq/python/ops/seq2seq.pyc in embedding_rnn_seq2seq(encoder_inputs, decoder_inputs, cell, num_encoder_symbols, num_decoder_symbols, embedding_size, output_projection, feed_previous, dtype, scope)
#     361         embedding_classes=num_encoder_symbols,
#     362         embedding_size=embedding_size)
# --> 363     _, encoder_state = rnn.static_rnn(encoder_cell, encoder_inputs, dtype=dtype)
#     364
#     365     # Decoder.
#
# /home/animesh/Programming/platforms/anaconda3/envs/snakes/lib/python2.7/site-packages/tensorflow/python/ops/rnn.pyc in static_rnn(cell, inputs, initial_state, dtype, sequence_length, scope)
#    1171         batch_size, input_size = input_shape[0], input_shape[1:]
#    1172         fixed_batch_size.merge_with(batch_size)
# -> 1173         for i, size in enumerate(input_size):
#    1174           if size.value is None:
#    1175             raise ValueError(
#
# /home/animesh/Programming/platforms/anaconda3/envs/snakes/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in __iter__(self)
#     479     """Returns `self.dims` if the rank is known, otherwise raises ValueError."""
#     480     if self._dims is None:
# --> 481       raise ValueError("Cannot iterate over a shape with unknown rank.")
#     482     else:
#     483       return iter(self._dims)
#
# ValueError: Cannot iterate over a shape with unknown rank.

# %%
prediction
# Out:
# <tf.Tensor 'Squeeze:0' shape=(85,) dtype=int64>

# %%
model_name = "Model3"
itera = 1

# %%
global_index = 0
data_size = len(dquestions)

# %%
# function to decode the encoded query:
def decode(encoded_list):
    '''
        function to decode the integer sequence
        @param
        encoded_list => the sequence of integers to decode
        @return => the string fromed by decoding the input sequence
    '''
    
    # generate the decoded words from the given list:
    decoded_list = [] # start with empty list
    for word in encoded_list:
        if(word in reverse_dictionary):
            decoded_list.append(reverse_dictionary[word])
        else:
            decoded_list.append('UNK')
    
    decoded_string = reduce(lambda x, y: x + " " + y, decoded_list)
    
    # return the decoded string
    return decoded_string.replace("<blank>", "")

# %%
# time to run this session:
'''
code snippet to run a tensorflow session for performing the training.
'''

''' 
    WARNING WARNING WARNING!!! This is the main training cell. 
    This cell will take a really really long time on low-end machines. It will however not crash your pc, since 
    I have bootstrapped the training in such a way that it loads a small chunk of data at a time to train.
'''

with tf.Session(graph=graph) as sess:
    # bring the global_index into current scope:
    global global_index
    
    # The saver object for saving and loading the model
    saver = tf.train.Saver(max_to_keep=2)
    
    # the path where the model will be saved 
    # let's visualize this graph in tensorboard:
    model_path = os.path.join(base_model_path, model_name)
    
    # create the summary_writer for tensorboard
    tensorboard_writer = tf.summary.FileWriter(model_path, graph=sess.graph)
    
    if(os.path.isfile(os.path.join(model_path, "checkpoint"))):
        # load the weights from the model
        # instead of global variable initializer, restore the graph:
        saver.restore(sess, tf.train.latest_checkpoint(model_path))
        
    else:
        
        # initialize all the variables
        sess.run(init)
    
    for ep in range((itera - 1) * no_of_epochs, itera * no_of_epochs):  # start the loop 
        
        start = global_index
        end = start + batch_size
            
        questions_raw = dquestions[start: end]
        queries_raw = dqueries[start: end]
            
        input_questions_batch = list(np.array(questions_raw).reshape(len(questions_raw), seqs_length))
        input_translate_batch = list(np.array(queries_raw).reshape(len(queries_raw), seqs_length))
            
        global_index = (global_index + batch_size) % data_size
        
        # construct the feed dictionary
        for i in range(len(input_questions_batch)):

            # execute the training op
            _, cost = sess.run([train_op, loss], feed_dict={input_data[0]: input_questions_batch[i], 
                                                           input_translation[0]: input_translate_batch[i]})
        
        if((ep + 1) % checkpoint_factor == 0):
            # print the log statements:
            print "epoch: " + str(ep + 1)
            print "================================================================================================="
            print "================================================================================================="
            print('loss = {}'.format(cost))
            # run a random prediction:
            random_index = np.random.randint(batch_size)
            ques = input_questions_batch[random_index]
            ideal_quer = input_translate_batch[random_index]
            mock = np.array([dictionary['<go>']] + [dictionary['blank'] for _ in range(seqs_length - 1)])
            
            quer = sess.run(prediction, feed_dict={input_data[0]: ques, input_translation[0]: mock})
            
            print "Input Question  : " + decode(ques)
            print "Ideal Output    : " + decode(ideal_quer)
            print "Output Received : " + decode(quer)
            
            print "\n=========================================================================================\n"
            print "================================================================================================="
            print "================================================================================================="
            
            # run the summary op also
            summary = sess.run(all_summaries, feed_dict={input_data[0]: input_questions_batch[i], 
                                                           input_translation[0]: input_translate_batch[i]})

            # add the generated summary to the fileWriter
            tensorboard_writer.add_summary(summary, (ep + 1))
            
            # save the model trained so far:
            saver.save(sess, os.path.join(model_path, model_name), global_step = (ep + 1))
# Out:
# epoch: 10
# =================================================================================================
# =================================================================================================
# loss = 80.7133331299
# Input Question  : what is who-two where you and i is ngœban
# Ideal Output    : <go> select who-two from <table> where you and i = ngœban <eos>
# Output Received : <go> select <go>     select
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 20
# =================================================================================================
# =================================================================================================
# loss = 221.906021118
# Input Question  : who is the villain in episode #7
# Ideal Output    : <go> select villains from <table> where # = 7 <eos>
# Output Received : <go>   select
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 30
# =================================================================================================
# =================================================================================================
# loss = 89.8720092773
# Input Question  : how many races were in 2009 with 0 wins
# Ideal Output    : <go> select races from <table> where season = 2009 and wins = 0 <eos>
# Output Received : <go> original  date
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 40
# =================================================================================================
# =================================================================================================
# loss = 56.2964859009
# Input Question  : what's the % with total value of 249887 and queens value of 6.8%
# Ideal Output    : <go> select % from <table> where total = 249887 and queens = 6.8% <eos>
# Output Received : <go> original by air by air air air original air air air
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 50
# =================================================================================================
# =================================================================================================
# loss = 70.6812438965
# Input Question  : what's the people-task orientation scale where extroverted, relationship-oriented is team type
# Ideal Output    : <go> select people-task orientation scale from <table> where extroverted, relationship-oriented = team type <eos>
# Output Received : <go> episode air episode episode episode episode air runner-up episode air " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " "
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 60
# =================================================================================================
# =================================================================================================
# loss = 26.5700683594
# Input Question  : what is the name of the constructor that has the circuit zeltweg airfield
# Ideal Output    : <go> select constructor from <table> where circuit = zeltweg airfield <eos>
# Output Received : <go> constructor constructor race constructor constructor constructor constructor constructor constructor constructor constructor race prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix prix
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 70
# =================================================================================================
# =================================================================================================
# loss = 41.8034172058
# Input Question  : what is the toatl number of caps where the name is hans blume
# Ideal Output    : <go> select count ( number of caps ) from <table> where name = hans blume <eos>
# Output Received : <go> number engine place place place place place engine engine number place place " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " " "
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 80
# =================================================================================================
# =================================================================================================
# loss = 25.5276641846
# Input Question  : what's the player whose mlb draft is 1st round - 2nd pick of 1995 draft ( padres)
# Ideal Output    : <go> select player from <table> where mlb draft = 1st round - 2nd pick of 1995 draft ( padres ) <eos>
# Output Received : <go> hometown hometown school hometown hometown hometown hometown hometown hometown draft draft draft draft hometown hometown tournament high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high high
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 90
# =================================================================================================
# =================================================================================================
# loss = 33.7555007935
# Input Question  : what position does cody ceci play
# Ideal Output    : <go> select position from <table> where player = cody ceci <eos>
# Output Received : <go> rockets draft rockets rockets rockets 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 2008
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 100
# =================================================================================================
# =================================================================================================
# loss = 4.09024381638
# Input Question  : what's the leading scorer where home is sacramento kings
# Ideal Output    : <go> select leading scorer from <table> where home = sacramento kings <eos>
# Output Received : <go> rebounds rebounds rebounds rebounds rebounds rebounds rebounds rebounds @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 110
# =================================================================================================
# =================================================================================================
# loss = 30.3903579712
# Input Question  : what are all the .308 winchester cartridge types with 38 for the 300 m group (mm)
# Ideal Output    : <go> select .308 winchester cartridge type from <table> where 300 m group (mm) = 38 <eos>
# Output Received : <go> mens mixed mens mixed mixed mixed mixed mens mixed mixed mens mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed mixed
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 120
# =================================================================================================
# =================================================================================================
# loss = 51.0783729553
# Input Question  : what is the power when ch# is tv-26 and dyfj-tv
# Ideal Output    : <go> select power (kw) from <table> where ch. # = tv-26 and callsign = dyfj-tv <eos>
# Output Received : <go> mixed mixed mixed mixed mixed mixed mixed mixed mixed nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation nation
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 130
# =================================================================================================
# =================================================================================================
# loss = 7.71926593781
# Input Question  : what is thea year the road closed april 13
# Ideal Output    : <go> select max ( year ) from <table> where road closed = april 13 <eos>
# Output Received : <go> thursday thursday thursday thursday thursday thursday thursday thursday day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day day
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 140
# =================================================================================================
# =================================================================================================
# loss = 51.2894935608
# Input Question  : what's the name of the county where 48.3% voted for bush
# Ideal Output    : <go> select county from <table> where bush% = 48.3% <eos>
# Output Received : <go> construction maryland no construction no championship construction no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 150
# =================================================================================================
# =================================================================================================
# loss = 17.9897136688
# Input Question  : who were the candidates in the maryland 5 district election?
# Ideal Output    : <go> select candidates from <table> where district = maryland 5 <eos>
# Output Received : <go> bonus bonus bonus bonus bonus bonus bonus bonus bonus incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent incumbent
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 160
# =================================================================================================
# =================================================================================================
# loss = 6.33336734772
# Input Question  : how many candidates are listed all together for the incumbent named bob clement
# Ideal Output    : <go> select count ( candidates ) from <table> where incumbent = bob clement <eos>
# Output Received : <go> (d) (d) (d) (d) (d) (d) (d) results (d) (d) (d) (d) 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974 1974
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 170
# =================================================================================================
# =================================================================================================
# loss = 7.02164268494
# Input Question  : who is the incumbent in district texas 15
# Ideal Output    : <go> select incumbent from <table> where district = texas 15 <eos>
# Output Received : <go> unopposed unopposed unopposed unopposed louisiana unopposed unopposed w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w. w.
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 180
# =================================================================================================
# =================================================================================================
# loss = 23.5913696289
# Input Question  : how many candidates ran in the race where the incumbent is j. l. pilcher
# Ideal Output    : <go> select count ( candidates ) from <table> where incumbent = j. l. pilcher <eos>
# Output Received : <go> m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m. m.
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 190
# =================================================================================================
# =================================================================================================
# loss = 13.0193681717
# Input Question  : who are the incumbent candidates from louisiana district 4
# Ideal Output    : <go> select incumbent from <table> where district = louisiana 4 <eos>
# Output Received : <go> r. f. m. f. f. f. m. f. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b.
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 200
# =================================================================================================
# =================================================================================================
# loss = 19.2897872925
# Input Question  : who were the candidates for election in tennessee district 5
# Ideal Output    : <go> select candidates from <table> where district = tennessee 5 <eos>
# Output Received : <go> r. 1914 re-elected b. kansas kansas b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b. b.
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 210
# =================================================================================================
# =================================================================================================
# loss = 20.6007652283
# Input Question  : what's the dbeingtribution with rsbac being unknown
# Ideal Output    : <go> select distribution from <table> where rsbac = unknown <eos>
# Output Received : <go> gender yrs) try yrs) try yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs) yrs)
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 220
# =================================================================================================
# =================================================================================================
# loss = 52.6365242004
# Input Question  : who is the the artbeingt with song title being " a little bitty tear "
# Ideal Output    : <go> select artist from <table> where song title = " a little bitty tear " <eos>
# Output Received : <go> kwh/kwp•y inflation inflation votes inflation won announced inflation acquired acquired trim acquired announced acquired comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb comb
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 230
# =================================================================================================
# =================================================================================================
# loss = 34.4115867615
# Input Question  : what's the pts with poles being smaller than 1.0 and motorcycle being aprilia and class being 250cc
# Ideal Output    : <go> select pts from <table> where poles < 1.0 and motorcycle = aprilia and class = 250cc <eos>
# Output Received : <go> actor pts primary primary primary primary primary primary primary actor primary primary primary actor primary primary bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay bay
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 240
# =================================================================================================
# =================================================================================================
# loss = 20.4346981049
# Input Question  : who is the co-presenter of the series seven (2007)
# Ideal Output    : <go> select co-presenter from <table> where series = seven (2007) <eos>
# Output Received : <go> extra away extra away away away away extra country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory country/territory
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 250
# =================================================================================================
# =================================================================================================
# loss = 11.3427257538
# Input Question  : what are all the school years where class aaaa is in gregory-portland?
# Ideal Output    : <go> select school year from <table> where class aaaa = gregory-portland <eos>
# Output Received : <go> situation class females situation (rank) wc situation situation moscow situation wc server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server server
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 260
# =================================================================================================
# =================================================================================================
# loss = 21.3067436218
# Input Question  : what are all played with a 3 dart avg is 92.06
# Ideal Output    : <go> select played from <table> where 3-dart average = 92.06 <eos>
# Output Received : <go> aaaa aaaa arrivals arrivals aaaa aaaa aaaa aaaa tourist aaaa 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07 2006-07
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 270
# =================================================================================================
# =================================================================================================
# loss = 23.6400737762
# Input Question  : what was the record when the game was played at cleveland municipal stadium
# Ideal Output    : <go> select record from <table> where game site = cleveland municipal stadium <eos>
# Output Received : <go> performer (2nd performer actor (2nd no performer cup site votes site actor voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice voice
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 280
# =================================================================================================
# =================================================================================================
# loss = 9.33130168915
# Input Question  : what was segment c when segment b was package printing?
# Ideal Output    : <go> select segment c from <table> where segment b = package printing <eos>
# Output Received : <go> segment segment segment segment segment b segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment segment
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 290
# =================================================================================================
# =================================================================================================
# loss = 16.8163719177
# Input Question  : when the team is ypiranga-sp what is the number of won games
# Ideal Output    : <go> select min ( won ) from <table> where team = ypiranga-sp <eos>
# Output Received : <go> general segment segment segment segment segment general segment difference segment segment 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 300
# =================================================================================================
# =================================================================================================
# loss = 28.8299560547
# Input Question  : what is the highest season for a bowl game of the 1993 independence bowl
# Ideal Output    : <go> select max ( season ) from <table> where bowl game = 1993 independence bowl <eos>
# Output Received : <go> first driver school/club segment ends school/club driver driver driver driver driver driver driver school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club school/club
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 310
# =================================================================================================
# =================================================================================================
# loss = 25.4311904907
# Input Question  : how many players had the most assists against new jersey
# Ideal Output    : <go> select count ( high assists ) from <table> where team = new jersey <eos>
# Output Received : <go> questions questions questions 20 site december 20 questions questions february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february february
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 320
# =================================================================================================
# =================================================================================================
# loss = 36.4863853455
# Input Question  : when is the latest game the bills had 21 first downs
# Ideal Output    : <go> select min ( game ) from <table> where bills first downs = 21 <eos>
# Output Received : <go> % % match site % % match % % % 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 330
# =================================================================================================
# =================================================================================================
# loss = 15.482260704
# Input Question  : name the notes for samangan
# Ideal Output    : <go> select notes from <table> where province = samangan <eos>
# Output Received : <go> donor average segment 20 april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april april
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 340
# =================================================================================================
# =================================================================================================
# loss = 33.7688903809
# Input Question  : what is the dpi for the scanner with a max page size of 216mm x 355mm
# Ideal Output    : <go> select dpi from <table> where max page size = 216mm x 355mm <eos>
# Output Received : <go> % avg. % segment avg. finish 20 venue avg. carlton avg. % march % % 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 350
# =================================================================================================
# =================================================================================================
# loss = 29.2519359589
# Input Question  : name the other name where glucose is 5000
# Ideal Output    : <go> select other name from <table> where [glucose](mg/dl) = 5000 <eos>
# Output Received : <go> driver segment segment segment driver (m) (m) 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 360
# =================================================================================================
# =================================================================================================
# loss = 56.48695755
# Input Question  : what is the release date of the bonus interview with peter purves
# Ideal Output    : <go> select release date from <table> where notes = bonus interview with peter purves <eos>
# Output Received : <go> rnd longitude driver longitude driver longitude (m) longitude notes named longitude 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 370
# =================================================================================================
# =================================================================================================
# loss = 20.0669841766
# Input Question  : how many athletes completed a trans 1 within 0:26
# Ideal Output    : <go> select count ( athlete ) from <table> where trans 1 = 0:26 <eos>
# Output Received : <go> segment pf segment skip driver skip pf segment skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip skip
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 380
# =================================================================================================
# =================================================================================================
# loss = 8.70192337036
# Input Question  : name the total number of going to for castle bytham, saxby and melton mowbray
# Ideal Output    : <go> select count ( going to ) from <table> where calling at = castle bytham, saxby, melton mowbray <eos>
# ...
# epoch: 890
# =================================================================================================
# =================================================================================================
# loss = 17.5319881439
# Input Question  : in how many events was puma 20 and abu dhabi 30
# Ideal Output    : <go> select count ( event ) from <table> where puma = 20 and abu dhabi = 30 <eos>
# Output Received : <go> pf pf category pf pf pf pf category pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 900
# =================================================================================================
# =================================================================================================
# loss = 34.764995575
# Input Question  : what is the production code for the episode written by kat likkel & denise downer
# Ideal Output    : <go> select production code from <table> where written by = kat likkel & denise downer <eos>
# Output Received : <go> pf category category pf female category category elapsed pf water pf female pf pf female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female female
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 910
# =================================================================================================
# =================================================================================================
# loss = 27.3383293152
# Input Question  : which aorist has imperfect form of bijasmo / bejasmo / besmo
# Ideal Output    : <go> select aorist from <table> where imperfect = bijasmo / bejasmo / besmo <eos>
# Output Received : <go> category skipper category category skipper category pf skipper pf elapsed steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 920
# =================================================================================================
# =================================================================================================
# loss = 3.6222755909
# Input Question  : what is every value for passing yards per game if rushing yards per game is 113.6
# Ideal Output    : <go> select passing yards per game from <table> where rushing yards per game = 113.6 <eos>
# Output Received : <go> pf category yards category category yards elapsed pf category category yards elapsed pf pf elapsed fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall fall
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 930
# =================================================================================================
# =================================================================================================
# loss = 0.0797127336264
# Input Question  : what is the ihsa music class for the mascot that is the lancers
# Ideal Output    : <go> select ihsa music class from <table> where mascot = lancers <eos>
# Output Received : <go> pf elapsed par category category (metres) elapsed pf category pf elapsed (metres) pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 940
# =================================================================================================
# =================================================================================================
# loss = 14.0003137589
# Input Question  : name the high assists for w 107–99 (ot)
# Ideal Output    : <go> select high assists from <table> where score = w 107–99 (ot) <eos>
# Output Received : <go> scored wall scored scored scored par scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 950
# =================================================================================================
# =================================================================================================
# loss = 27.9998703003
# Input Question  : how long has the longest song spent in the top 10
# Ideal Output    : <go> select max ( weeks in top 10 ) from <table> <eos>
# Output Received : <go> steals scored category elapsed scored category scored category pf pf scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored scored
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 960
# =================================================================================================
# =================================================================================================
# loss = 0.000742727890611
# Input Question  : what team is in the city of rock island
# Ideal Output    : <go> select team name from <table> where city = rock island <eos>
# Output Received : <go> category category category category category category category category pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa pa
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 970
# =================================================================================================
# =================================================================================================
# loss = 30.9744186401
# Input Question  : what is the production code for "chuck versus the balcony"
# Ideal Output    : <go> select production code from <table> where title = "chuck versus the balcony" <eos>
# Output Received : <go> details category category steals details category category category par details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details details
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 980
# =================================================================================================
# =================================================================================================
# loss = 10.6079149246
# Input Question  : what's the nickname of the team with enrollment of 40747
# Ideal Output    : <go> select team nickname from <table> where enrollment = 40747 <eos>
# Output Received : <go> category water category category category category category category category steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals steals
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 990
# =================================================================================================
# =================================================================================================
# loss = 148.446807861
# Input Question  : what's the number of the 1.0.9 release version
# Ideal Output    : <go> select count ( version ) from <table> where release = 1.0.9 <eos>
# Output Received : <go> par par par par par par par dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk dirk
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================
# epoch: 1000
# =================================================================================================
# =================================================================================================
# loss = 28.1461200714
# Input Question  : what are the 2nd place values for the country whose 1st place years are 2004, 2005, 2009, 2010, and 2011
# Ideal Output    : <go> select second place from <table> where first place winning year(s) (if applicable) = 2004, 2005, 2009, 2010, 2011 <eos>
# Output Received : <go> par par par par par par par par par par par par par par par par par category par pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf pf
#
# =========================================================================================
#
# =================================================================================================
# =================================================================================================

# %% [markdown]
# # The training is now complete. Let's calculate the accuracy and also, try feeding in some random inputs to test how well the model works in the next notebook.
